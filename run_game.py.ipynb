# %%
import logging

from config import Config
from game import Game
from deck import Deck
from player import Player
from strategy import Strategy

# %load_ext autoreload
# %autoreload 2

# %%
logging.basicConfig(level=logging.INFO)

# %%
config = Config("config.yaml")
# Out:
# INFO:config:Reading configuration from: config.yaml
# INFO:config:Finished reading configuration.

# %%
deck = Deck(config)

# %%
game = Game(config, deck)

# %%
for name in "Henk", "Ingrid", "Piet", "Klaas":
    strategy = Strategy(config)
    player = Player(config, name, strategy)
    game.add_player(player)

# %%
game.run()
# Out:
# INFO:game:**** Starting turn 1 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Bok by Ingrid.
# INFO:game:Bids: Henk: 83.51, Piet: 90.00, Klaas: 90.00
# INFO:game:Player Piet wins the auction for 90.
# INFO:game:Auctioneer Ingrid choses to buy the Bok.
# INFO:game:Ingrid buys the Bok for 90, remaining budget equals 0.
# INFO:game:Piet sells the Bok for 90, budget now equals 180.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 2 with auctioneer Klaas ****
# INFO:game:Applying bonus of 50 for animal Ezel.
# INFO:game:Auctioning animal Ezel by Klaas.
# INFO:game:Bids: Henk: 140.00, Ingrid: 50.00, Piet: 230.00
# INFO:game:Player Piet wins the auction for 150.
# INFO:game:Piet buys the Ezel for 150, remaining budget equals 80.
# INFO:game:Klaas sells the Ezel for 150, budget now equals 290.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 3 with auctioneer Henk ****
# INFO:game:Applying bonus of 100 for animal Ezel.
# INFO:game:Auctioning animal Ezel by Henk.
# INFO:game:Bids: Ingrid: 150.00, Piet: 180.00, Klaas: 390.00
# INFO:game:Player Klaas wins the auction for 190.
# INFO:game:Auctioneer Henk choses to buy the Ezel.
# INFO:game:Henk buys the Ezel for 190, remaining budget equals 50.
# INFO:game:Klaas sells the Ezel for 190, budget now equals 580.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 4 with auctioneer Piet ****
# INFO:game:Auctioning animal Kat by Piet.
# INFO:game:Bids: Henk: 30.30, Ingrid: 146.71, Klaas: 73.30
# INFO:game:Player Ingrid wins the auction for 80.
# INFO:game:Ingrid buys the Kat for 80, remaining budget equals 70.
# INFO:game:Piet sells the Kat for 80, budget now equals 260.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Ezel (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 5 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Hond by Ingrid.
# INFO:game:Bids: Henk: 50.00, Piet: 83.94, Klaas: 109.07
# INFO:game:Player Klaas wins the auction for 90.
# INFO:game:Klaas buys the Hond for 90, remaining budget equals 490.
# INFO:game:Ingrid sells the Hond for 90, budget now equals 160.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 6 with auctioneer Klaas ****
# INFO:game:Auctioning animal Gans by Klaas.
# INFO:game:Bids: Henk: 50.00, Ingrid: 19.58, Piet: 88.46
# INFO:game:Player Piet wins the auction for 60.
# INFO:game:Piet buys the Gans for 60, remaining budget equals 200.
# INFO:game:Klaas sells the Gans for 60, budget now equals 550.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 7 with auctioneer Henk ****
# INFO:game:Auctioning animal Koe by Henk.
# INFO:game:Bids: Ingrid: 160.00, Piet: 200.00, Klaas: 550.00
# INFO:game:Player Klaas wins the auction for 210.
# INFO:game:Klaas buys the Koe for 210, remaining budget equals 340.
# INFO:game:Henk sells the Koe for 210, budget now equals 260.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Piet)
# INFO:game:Henk wants to trade a Ezel with Piet for 260.00.
# INFO:game:Piet counters with an offer of 0.00.
# INFO:game:Henk wins the trade for a Ezel from Piet.
# INFO:game:Henk pays 260 and gains 0, budget is now 0.
# INFO:game:Piet pays 0 and gains 260, budget is now 460.
# INFO:game:**** Starting turn 8 with auctioneer Piet ****
# INFO:game:Auctioning animal Gans by Piet.
# INFO:game:Bids: Henk: 0.00, Ingrid: 19.49, Klaas: 49.18
# INFO:game:Player Klaas wins the auction for 30.
# INFO:game:Auctioneer Piet choses to buy the Gans.
# INFO:game:Piet buys the Gans for 30, remaining budget equals 430.
# INFO:game:Klaas sells the Gans for 30, budget now equals 370.
# INFO:game:Starting trading phase for Piet.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 9 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Paard by Ingrid.
# INFO:game:Bids: Henk: 0.00, Piet: 430.00, Klaas: 370.00
# INFO:game:Player Piet wins the auction for 380.
# INFO:game:Piet buys the Paard for 380, remaining budget equals 50.
# INFO:game:Ingrid sells the Paard for 380, budget now equals 540.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 10 with auctioneer Klaas ****
# INFO:game:Auctioning animal Varken by Klaas.
# INFO:game:Bids: Henk: 0.00, Ingrid: 540.00, Piet: 50.00
# INFO:game:Player Ingrid wins the auction for 60.
# INFO:game:Auctioneer Klaas choses to buy the Varken.
# INFO:game:Klaas buys the Varken for 60, remaining budget equals 310.
# INFO:game:Ingrid sells the Varken for 60, budget now equals 600.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 11 with auctioneer Henk ****
# INFO:game:Auctioning animal Schaap by Henk.
# INFO:game:Bids: Ingrid: 219.01, Piet: 50.00, Klaas: 161.06
# INFO:game:Player Ingrid wins the auction for 170.
# INFO:game:Ingrid buys the Schaap for 170, remaining budget equals 430.
# INFO:game:Henk sells the Schaap for 170, budget now equals 170.
# INFO:game:Starting trading phase for Henk.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 12 with auctioneer Piet ****
# INFO:game:Auctioning animal Schaap by Piet.
# INFO:game:Bids: Henk: 170.00, Ingrid: 231.76, Klaas: 144.91
# INFO:game:Player Ingrid wins the auction for 180.
# INFO:game:Ingrid buys the Schaap for 180, remaining budget equals 250.
# INFO:game:Piet sells the Schaap for 180, budget now equals 230.
# INFO:game:Starting trading phase for Piet.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 13 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Kat by Ingrid.
# INFO:game:Bids: Henk: 21.40, Piet: 46.00, Klaas: 65.95
# INFO:game:Player Klaas wins the auction for 60.
# INFO:game:Auctioneer Ingrid choses to buy the Kat.
# INFO:game:Ingrid buys the Kat for 60, remaining budget equals 190.
# INFO:game:Klaas sells the Kat for 60, budget now equals 370.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 14 with auctioneer Klaas ****
# INFO:game:Auctioning animal Haan by Klaas.
# INFO:game:Bids: Henk: 5.72, Ingrid: 7.26, Piet: 5.92
# INFO:game:Player Ingrid wins the auction for 20.
# INFO:game:Ingrid buys the Haan for 20, remaining budget equals 170.
# INFO:game:Klaas sells the Haan for 20, budget now equals 390.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 15 with auctioneer Henk ****
# INFO:game:Auctioning animal Schaap by Henk.
# INFO:game:Bids: Ingrid: 170.00, Piet: 195.05, Klaas: 128.76
# INFO:game:Player Piet wins the auction for 180.
# INFO:game:Piet buys the Schaap for 180, remaining budget equals 50.
# INFO:game:Henk sells the Schaap for 180, budget now equals 350.
# INFO:game:Starting trading phase for Henk.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 16 with auctioneer Piet ****
# INFO:game:Applying bonus of 200 for animal Ezel.
# INFO:game:Auctioning animal Ezel by Piet.
# INFO:game:Bids: Henk: 442.94, Ingrid: 251.33, Klaas: 433.46
# INFO:game:Player Henk wins the auction for 440.
# INFO:game:Henk buys the Ezel for 440, remaining budget equals 110.
# INFO:game:Piet sells the Ezel for 440, budget now equals 690.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Schaap (Ingrid)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 17 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Hond by Ingrid.
# INFO:game:Bids: Henk: 110.00, Piet: 57.55, Klaas: 109.74
# INFO:game:Player Henk wins the auction for 110.
# INFO:game:Auctioneer Ingrid choses to buy the Hond.
# INFO:game:Ingrid buys the Hond for 110, remaining budget equals 260.
# INFO:game:Henk sells the Hond for 110, budget now equals 220.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Hond (Klaas), Schaap (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 18 with auctioneer Klaas ****
# INFO:game:Auctioning animal Varken by Klaas.
# INFO:game:Bids: Henk: 220.00, Ingrid: 260.00, Piet: 481.00
# INFO:game:Player Piet wins the auction for 270.
# INFO:game:Auctioneer Klaas choses to buy the Varken.
# INFO:game:Klaas buys the Varken for 270, remaining budget equals 320.
# INFO:game:Piet sells the Varken for 270, budget now equals 960.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Hond (Ingrid)
# INFO:game:Klaas wants to trade a Hond with Ingrid for 98.74.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Hond from Ingrid.
# INFO:game:Klaas pays 100 and gains 0, budget is now 220.
# INFO:game:Ingrid pays 0 and gains 100, budget is now 360.
# INFO:game:**** Starting turn 19 with auctioneer Henk ****
# INFO:game:Auctioning animal Koe by Henk.
# INFO:game:Bids: Ingrid: 360.00, Piet: 476.05, Klaas: 220.00
# INFO:game:Player Piet wins the auction for 370.
# INFO:game:Piet buys the Koe for 370, remaining budget equals 590.
# INFO:game:Henk sells the Koe for 370, budget now equals 590.
# INFO:game:Starting trading phase for Henk.
# INFO:game:No suitable trading options.
# INFO:game:**** Starting turn 20 with auctioneer Piet ****
# INFO:game:Auctioning animal Varken by Piet.
# INFO:game:Bids: Henk: 220.85, Ingrid: 360.00, Klaas: 220.00
# INFO:game:Player Ingrid wins the auction for 230.
# INFO:game:Auctioneer Piet choses to buy the Varken.
# INFO:game:Piet buys the Varken for 230, remaining budget equals 360.
# INFO:game:Ingrid sells the Varken for 230, budget now equals 590.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Schaap (Ingrid), Varken (Klaas), Koe (Klaas)
# INFO:game:Piet wants to trade a Varken with Klaas for 267.74.
# INFO:game:Klaas counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Varken from Klaas.
# INFO:game:Piet pays 270 and gains 0, budget is now 90.
# INFO:game:Klaas pays 0 and gains 270, budget is now 490.
# INFO:game:**** Starting turn 21 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Haan by Ingrid.
# INFO:game:Bids: Henk: 8.00, Piet: 4.06, Klaas: 7.91
# INFO:game:Player Henk wins the auction for 20.
# INFO:game:Henk buys the Haan for 20, remaining budget equals 570.
# INFO:game:Ingrid sells the Haan for 20, budget now equals 610.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Haan (Henk), Schaap (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 22 with auctioneer Klaas ****
# INFO:game:Applying bonus of 500 for animal Ezel.
# INFO:game:Auctioning animal Ezel by Klaas.
# INFO:game:Bids: Henk: 918.24, Ingrid: 250.16, Piet: 48.91
# INFO:game:Player Henk wins the auction for 260.
# INFO:game:Auctioneer Klaas choses to buy the Ezel.
# INFO:game:Klaas buys the Ezel for 260, remaining budget equals 730.
# INFO:game:Henk sells the Ezel for 260, budget now equals 1330.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Ezel (Henk), Varken (Piet), Koe (Piet)
# INFO:game:Klaas wants to trade a Varken with Piet for 430.98.
# INFO:game:Piet counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Varken from Piet.
# INFO:game:Klaas pays 430 and gains 0, budget is now 300.
# INFO:game:Piet pays 0 and gains 430, budget is now 1020.
# INFO:game:**** Starting turn 23 with auctioneer Henk ****
# INFO:game:Auctioning animal Haan by Henk.
# INFO:game:Bids: Ingrid: 7.64, Piet: 2.20, Klaas: 7.03
# INFO:game:Player Ingrid wins the auction for 20.
# INFO:game:Ingrid buys the Haan for 20, remaining budget equals 1090.
# INFO:game:Henk sells the Haan for 20, budget now equals 1350.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Haan (Ingrid), Ezel (Klaas)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 24 with auctioneer Piet ****
# INFO:game:Auctioning animal Kat by Piet.
# INFO:game:Bids: Henk: 24.76, Ingrid: 163.80, Klaas: 58.60
# INFO:game:Player Ingrid wins the auction for 70.
# INFO:game:Ingrid buys the Kat for 70, remaining budget equals 1020.
# INFO:game:Piet sells the Kat for 70, budget now equals 1090.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Schaap (Ingrid), Varken (Klaas), Koe (Klaas)
# INFO:game:Piet wants to trade a Schaap with Ingrid for 200.55.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Schaap from Ingrid.
# INFO:game:Piet pays 200 and gains 0, budget is now 890.
# INFO:game:Ingrid pays 0 and gains 200, budget is now 1220.
# INFO:game:**** Starting turn 25 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Koe by Ingrid.
# INFO:game:Bids: Henk: 404.39, Piet: 489.48, Klaas: 300.00
# INFO:game:Player Piet wins the auction for 410.
# INFO:game:Auctioneer Ingrid choses to buy the Koe.
# INFO:game:Ingrid buys the Koe for 410, remaining budget equals 810.
# INFO:game:Piet sells the Koe for 410, budget now equals 1300.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Haan (Henk), Schaap (Piet), Koe (Piet, Klaas)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 26 with auctioneer Klaas ****
# INFO:game:Auctioning animal Schaap by Klaas.
# INFO:game:Bids: Henk: 93.70, Ingrid: 235.15, Piet: 380.62
# INFO:game:Player Piet wins the auction for 250.
# INFO:game:Piet buys the Schaap for 250, remaining budget equals 1050.
# INFO:game:Klaas sells the Schaap for 250, budget now equals 550.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Ezel (Henk), Varken (Piet), Koe (Ingrid, Piet)
# INFO:game:Klaas does not want to trade.
# INFO:game:**** Starting turn 27 with auctioneer Henk ****
# INFO:game:Auctioning animal Kat by Henk.
# INFO:game:Bids: Ingrid: 176.49, Piet: 4.47, Klaas: 51.25
# INFO:game:Player Ingrid wins the auction for 60.
# INFO:game:Ingrid buys the Kat for 60, remaining budget equals 750.
# INFO:game:Henk sells the Kat for 60, budget now equals 1410.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Haan (Ingrid), Ezel (Klaas)
# INFO:game:Henk wants to trade a Haan with Ingrid for 4.91.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Henk wins the trade for a Haan from Ingrid.
# INFO:game:Henk pays 0 and gains 0, budget is now 1410.
# INFO:game:Ingrid pays 0 and gains 0, budget is now 750.
# INFO:game:**** Starting turn 28 with auctioneer Piet ****
# INFO:game:Auctioning animal Varken by Piet.
# INFO:game:Bids: Henk: 63.34, Ingrid: 750.00, Klaas: 487.99
# INFO:game:Player Ingrid wins the auction for 500.
# INFO:game:Ingrid buys the Varken for 500, remaining budget equals 250.
# INFO:game:Piet sells the Varken for 500, budget now equals 1550.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Schaap (Ingrid), Varken (Ingrid, Klaas), Koe (Ingrid, Klaas)
# INFO:game:Piet wants to trade a Schaap with Ingrid for 459.33.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Schaap from Ingrid.
# INFO:game:Piet pays 460 and gains 0, budget is now 1090.
# INFO:game:Ingrid pays 0 and gains 460, budget is now 710.
# INFO:game:**** Starting turn 29 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Paard by Ingrid.
# INFO:game:Bids: Henk: 1410.00, Piet: 1090.00, Klaas: 550.00
# INFO:game:Player Henk wins the auction for 1100.
# INFO:game:Henk buys the Paard for 1100, remaining budget equals 310.
# INFO:game:Ingrid sells the Paard for 1100, budget now equals 1810.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Haan (Henk), Varken (Piet, Klaas), Koe (Piet, Klaas)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 30 with auctioneer Klaas ****
# INFO:game:Auctioning animal Hond by Klaas.
# INFO:game:Bids: Henk: 310.00, Ingrid: 287.49, Piet: 36.62
# INFO:game:Player Henk wins the auction for 300.
# INFO:game:Henk buys the Hond for 300, remaining budget equals 10.
# INFO:game:Klaas sells the Hond for 300, budget now equals 850.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Hond (Henk), Ezel (Henk), Varken (Ingrid, Piet), Koe (Ingrid, Piet)
# INFO:game:Klaas wants to trade a Koe with Ingrid for 513.80.
# INFO:game:Ingrid counters with an offer of 1810.00.
# INFO:game:Klaas loses the trade for a Koe to Ingrid.
# INFO:game:Klaas pays 510 and gains 1810, budget is now 2150.
# INFO:game:Ingrid pays 1810 and gains 510, budget is now 510.
# INFO:game:**** Starting turn 31 with auctioneer Henk ****
# INFO:game:Auctioning animal Paard by Henk.
# INFO:game:Bids: Ingrid: 510.00, Piet: 1090.00, Klaas: 868.48
# INFO:game:Player Piet wins the auction for 880.
# INFO:game:Piet buys the Paard for 880, remaining budget equals 210.
# INFO:game:Henk sells the Paard for 880, budget now equals 890.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Haan (Ingrid), Hond (Klaas), Ezel (Klaas), Paard (Piet)
# INFO:game:Henk wants to trade a Paard with Piet for 890.00.
# INFO:game:Piet counters with an offer of 0.00.
# INFO:game:Henk wins the trade for a Paard from Piet.
# INFO:game:Henk pays 890 and gains 0, budget is now 0.
# INFO:game:Piet pays 0 and gains 890, budget is now 1100.
# INFO:game:**** Starting turn 32 with auctioneer Piet ****
# INFO:game:Auctioning animal Gans by Piet.
# INFO:game:Bids: Henk: 0.00, Ingrid: 19.87, Klaas: 43.70
# INFO:game:Player Klaas wins the auction for 30.
# INFO:game:Auctioneer Piet choses to buy the Gans.
# INFO:game:Piet buys the Gans for 30, remaining budget equals 1070.
# INFO:game:Klaas sells the Gans for 30, budget now equals 2180.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Ingrid, Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet wants to trade a Paard with Henk for 738.93.
# INFO:game:Henk counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Paard from Henk.
# INFO:game:Piet pays 740 and gains 0, budget is now 330.
# INFO:game:Henk pays 0 and gains 740, budget is now 740.
# INFO:game:**** Starting turn 33 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Bok by Ingrid.
# INFO:game:Bids: Henk: 116.88, Piet: 249.79, Klaas: 442.04
# INFO:game:Player Klaas wins the auction for 260.
# INFO:game:Auctioneer Ingrid choses to buy the Bok.
# INFO:game:Ingrid buys the Bok for 260, remaining budget equals 250.
# INFO:game:Klaas sells the Bok for 260, budget now equals 2440.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Haan (Henk), Varken (Piet, Klaas), Koe (Piet)
# INFO:game:Ingrid wants to trade a Haan with Henk for 7.79.
# INFO:game:Henk counters with an offer of 8.81.
# INFO:game:Ingrid loses the trade for a Haan to Henk.
# INFO:game:Ingrid pays 10 and gains 10, budget is now 250.
# INFO:game:Henk pays 10 and gains 10, budget is now 740.
# INFO:game:**** Starting turn 34 with auctioneer Klaas ****
# INFO:game:Auctioning animal Gans by Klaas.
# INFO:game:Bids: Henk: 17.87, Ingrid: 19.78, Piet: 129.60
# INFO:game:Player Piet wins the auction for 30.
# INFO:game:Auctioneer Klaas choses to buy the Gans.
# INFO:game:Klaas buys the Gans for 30, remaining budget equals 2410.
# INFO:game:Piet sells the Gans for 30, budget now equals 360.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Gans (Piet), Hond (Henk), Ezel (Henk), Varken (Ingrid, Piet)
# INFO:game:Klaas wants to trade a Varken with Ingrid for 433.61.
# INFO:game:Ingrid counters with an offer of 250.00.
# INFO:game:Klaas wins the trade for a Varken from Ingrid.
# INFO:game:Klaas pays 430 and gains 250, budget is now 2230.
# INFO:game:Ingrid pays 250 and gains 430, budget is now 430.
# INFO:game:**** Starting turn 35 with auctioneer Henk ****
# INFO:game:Auctioning animal Paard by Henk.
# INFO:game:Bids: Ingrid: 430.00, Piet: 360.00, Klaas: 835.19
# INFO:game:Player Klaas wins the auction for 440.
# INFO:game:Auctioneer Henk choses to buy the Paard.
# INFO:game:Henk buys the Paard for 440, remaining budget equals 300.
# INFO:game:Klaas sells the Paard for 440, budget now equals 2670.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Hond (Klaas), Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 36 with auctioneer Piet ****
# INFO:game:Auctioning animal Bok by Piet.
# INFO:game:Bids: Henk: 102.03, Ingrid: 357.50, Klaas: 431.89
# INFO:game:Player Klaas wins the auction for 370.
# INFO:game:Klaas buys the Bok for 370, remaining budget equals 2300.
# INFO:game:Piet sells the Bok for 370, budget now equals 730.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Gans (Klaas), Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet wants to trade a Koe with Ingrid for 357.94.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Koe from Ingrid.
# INFO:game:Piet pays 360 and gains 0, budget is now 370.
# INFO:game:Ingrid pays 0 and gains 360, budget is now 790.
# INFO:game:**** Starting turn 37 with auctioneer Ingrid ****
# INFO:game:Auctioning animal Haan by Ingrid.
# INFO:game:Bids: Henk: 19.51, Piet: 0.45, Klaas: 6.76
# INFO:game:Player Henk wins the auction for 20.
# INFO:game:Henk buys the Haan for 20, remaining budget equals 280.
# INFO:game:Ingrid sells the Haan for 20, budget now equals 810.
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 38 with auctioneer Klaas ****
# INFO:game:Auctioning animal Bok by Klaas.
# INFO:game:Bids: Henk: 29.27, Ingrid: 355.86, Piet: 20.66
# INFO:game:Player Ingrid wins the auction for 40.
# INFO:game:Auctioneer Klaas choses to buy the Bok.
# INFO:game:Klaas buys the Bok for 40, remaining budget equals 2260.
# INFO:game:Ingrid sells the Bok for 40, budget now equals 850.
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Gans (Piet), Hond (Henk), Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas does not want to trade.
# INFO:game:**** Starting turn 39 with auctioneer Henk ****
# INFO:game:Auctioning animal Koe by Henk.
# INFO:game:Bids: Ingrid: 850.00, Piet: 370.00, Klaas: 491.10
# INFO:game:Player Ingrid wins the auction for 500.
# INFO:game:Ingrid buys the Koe for 500, remaining budget equals 350.
# INFO:game:Henk sells the Koe for 500, budget now equals 780.
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Hond (Klaas), Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 40 with auctioneer Piet ****
# INFO:game:Auctioning animal Hond by Piet.
# INFO:game:Bids: Henk: 488.09, Ingrid: 286.16, Klaas: 109.23
# INFO:game:Player Henk wins the auction for 300.
# INFO:game:Henk buys the Hond for 300, remaining budget equals 480.
# INFO:game:Piet sells the Hond for 300, budget now equals 670.
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Gans (Klaas), Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet wants to trade a Gans with Klaas for 88.85.
# INFO:game:Klaas counters with an offer of 42.28.
# INFO:game:Piet wins the trade for a Gans from Klaas.
# INFO:game:Piet pays 90 and gains 40, budget is now 620.
# INFO:game:Klaas pays 40 and gains 90, budget is now 2310.
# INFO:game:**** Starting turn 41 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 42 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Hond (Henk), Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas wants to trade a Ezel with Henk for 419.40.
# INFO:game:Henk counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Ezel from Henk.
# INFO:game:Klaas pays 420 and gains 0, budget is now 1890.
# INFO:game:Henk pays 0 and gains 420, budget is now 900.
# INFO:game:**** Starting turn 43 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Hond (Klaas), Ezel (Klaas), Paard (Piet)
# INFO:game:Henk wants to trade a Hond with Klaas for 342.05.
# INFO:game:Klaas counters with an offer of 0.00.
# INFO:game:Henk wins the trade for a Hond from Klaas.
# INFO:game:Henk pays 340 and gains 0, budget is now 560.
# INFO:game:Klaas pays 0 and gains 340, budget is now 2230.
# INFO:game:**** Starting turn 44 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet wants to trade a Paard with Henk for 620.00.
# INFO:game:Henk counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Paard from Henk.
# INFO:game:Piet pays 620 and gains 0, budget is now 0.
# INFO:game:Henk pays 0 and gains 620, budget is now 1180.
# INFO:game:**** Starting turn 45 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 46 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Hond (Henk), Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas wants to trade a Bok with Ingrid for 437.19.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Bok from Ingrid.
# INFO:game:Klaas pays 440 and gains 0, budget is now 1790.
# INFO:game:Ingrid pays 0 and gains 440, budget is now 790.
# INFO:game:**** Starting turn 47 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Hond (Klaas), Ezel (Klaas), Paard (Piet)
# INFO:game:Henk wants to trade a Hond with Klaas for 916.50.
# INFO:game:Klaas counters with an offer of 92.01.
# INFO:game:Henk wins the trade for a Hond from Klaas.
# INFO:game:Henk pays 920 and gains 90, budget is now 350.
# INFO:game:Klaas pays 90 and gains 920, budget is now 2620.
# INFO:game:**** Starting turn 48 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 49 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 50 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas does not want to trade.
# INFO:game:**** Starting turn 51 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 52 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 53 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 54 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas does not want to trade.
# INFO:game:**** Starting turn 55 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 56 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 57 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 58 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas wants to trade a Ezel with Henk for 526.16.
# INFO:game:Henk counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Ezel from Henk.
# INFO:game:Klaas pays 530 and gains 0, budget is now 2090.
# INFO:game:Henk pays 0 and gains 530, budget is now 880.
# INFO:game:**** Starting turn 59 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk wants to trade a Paard with Piet for 441.88.
# INFO:game:Piet counters with an offer of 0.00.
# INFO:game:Henk wins the trade for a Paard from Piet.
# INFO:game:Henk pays 440 and gains 0, budget is now 440.
# INFO:game:Piet pays 0 and gains 440, budget is now 440.
# INFO:game:**** Starting turn 60 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 61 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid wants to trade a Bok with Klaas for 334.18.
# INFO:game:Klaas counters with an offer of 0.00.
# INFO:game:Ingrid wins the trade for a Bok from Klaas.
# INFO:game:Ingrid pays 330 and gains 0, budget is now 460.
# INFO:game:Klaas pays 0 and gains 330, budget is now 2420.
# INFO:game:**** Starting turn 62 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas does not want to trade.
# INFO:game:**** Starting turn 63 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 64 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet wants to trade a Varken with Klaas for 55.27.
# INFO:game:Klaas counters with an offer of 0.00.
# INFO:game:Piet wins the trade for a Varken from Klaas.
# INFO:game:Piet pays 60 and gains 0, budget is now 380.
# INFO:game:Klaas pays 0 and gains 60, budget is now 2480.
# INFO:game:**** Starting turn 65 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 66 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas wants to trade a Bok with Ingrid for 437.19.
# INFO:game:Ingrid counters with an offer of 354.21.
# INFO:game:Klaas wins the trade for a Bok from Ingrid.
# INFO:game:Klaas pays 440 and gains 350, budget is now 2390.
# INFO:game:Ingrid pays 350 and gains 440, budget is now 550.
# INFO:game:**** Starting turn 67 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:**** Starting turn 68 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 69 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid wants to trade a Bok with Klaas for 334.18.
# INFO:game:Klaas counters with an offer of 0.00.
# INFO:game:Ingrid wins the trade for a Bok from Klaas.
# INFO:game:Ingrid pays 330 and gains 0, budget is now 220.
# INFO:game:Klaas pays 0 and gains 330, budget is now 2720.
# INFO:game:**** Starting turn 70 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas wants to trade a Bok with Ingrid for 437.19.
# INFO:game:Ingrid counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Bok from Ingrid.
# INFO:game:Klaas pays 440 and gains 0, budget is now 2280.
# INFO:game:Ingrid pays 0 and gains 440, budget is now 660.
# INFO:game:**** Starting turn 71 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk wants to trade a Ezel with Klaas for 148.11.
# INFO:game:Klaas counters with an offer of 0.00.
# INFO:game:Henk wins the trade for a Ezel from Klaas.
# INFO:game:Henk pays 150 and gains 0, budget is now 290.
# INFO:game:Klaas pays 0 and gains 150, budget is now 2430.
# INFO:game:**** Starting turn 72 with auctioneer Piet ****
# INFO:game:Starting trading phase for Piet.
# INFO:game:Found trading options: Varken (Klaas), Koe (Ingrid), Paard (Henk)
# INFO:game:Piet does not want to trade.
# INFO:game:**** Starting turn 73 with auctioneer Ingrid ****
# INFO:game:Starting trading phase for Ingrid.
# INFO:game:Found trading options: Bok (Klaas), Koe (Piet)
# INFO:game:Ingrid does not want to trade.
# INFO:game:**** Starting turn 74 with auctioneer Klaas ****
# INFO:game:Starting trading phase for Klaas.
# INFO:game:Found trading options: Bok (Ingrid), Ezel (Henk), Varken (Piet)
# INFO:game:Klaas wants to trade a Ezel with Henk for 482.47.
# INFO:game:Henk counters with an offer of 0.00.
# INFO:game:Klaas wins the trade for a Ezel from Henk.
# INFO:game:Klaas pays 480 and gains 0, budget is now 1950.
# INFO:game:Henk pays 0 and gains 480, budget is now 770.
# INFO:game:**** Starting turn 75 with auctioneer Henk ****
# INFO:game:Starting trading phase for Henk.
# INFO:game:Found trading options: Ezel (Klaas), Paard (Piet)
# INFO:game:Henk does not want to trade.
# INFO:game:Final scores: {'Henk': 2130, 'Ingrid': 1020, 'Piet': 2700, 'Klaas': 7050}
# {'Henk': 2130, 'Ingrid': 1020, 'Piet': 2700, 'Klaas': 7050}

# %%
game._owners
# Out:
#         Haan  Gans  Kat  Hond  Schaap  Bok  Ezel  Varken  Koe  Paard
# Henk       4     0    0     4       0    0     1       0    0      2
# Ingrid     0     0    4     0       0    1     0       0    2      0
# Piet       0     4    0     0       4    0     0       2    2      2
# Klaas      0     0    0     0       0    3     3       2    0      0
